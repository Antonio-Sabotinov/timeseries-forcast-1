# %%
'''
Vorhandene Modelle - 02.08.2026

phi4-mini:latest      
deepseek-r1:8b      
llama3.2:latest   

'''

# %%
from utils.interactive_chart import get_data
from utils.llm_analysis import analyze_dataframe

df = get_data("META", start="2025-01-01", indicators=["sma", "rsi", "macd"])

antwort = analyze_dataframe(df, "Wie ist der aktuelle Trend? Deutet der RSI auf eine überkaufte Situation hin?", model="deepseek-r1")
print(antwort)
# Out:
# Basierend auf den Statistischen Kennzahlen und dem Letzte 15 Datenpunkten, kann ich folgende Auswertungen vornehmen:
#
# **Aktueller Trend:** Der aktuelle Trend scheint zu schwanken und nicht kontinuierlich. Der Preis verläuft um die Mittelwerte herum und zeigt sich nicht in einer klaren Aufwärts- oder Abschwankung hin.
#
# **RSI:**
# Das Relative Stärkeindiz (RSI) ist ein technisches Analyseinstrument, das den Mzustand des Handels und der Marktstimmung anzeigt. Der RSI-Wert kann zwischen 0 (zu schwach) und 100 (zu stark) liegen.
#
# Im Laufe der letzten 15 Tage liegt der RSI-Wert weit über 50, was darauf hindeutet, dass die Aktie in einer Phase der Stärke liegt. Ein RSI-Wert > 70 bedeutet, dass die Aktie zu sehr überkauft ist.
#
# ...

# %%
from utils.interactive_chart import get_data
from utils.llm_analysis import analyze_dataframe

df = get_data("META", start="2024-01-01", indicators=["sma", "rsi", "macd"])

antwort = analyze_dataframe(df, "Wie ist der aktuelle Trend? Deutet der RSI auf eine überkaufte Situation hin?", )
print(antwort)
