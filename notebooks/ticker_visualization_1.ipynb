# %%
TICKER = "IREN"
INTERVAL = "1d"
START = "2025-02-01"
END  = "2026-09-14"

# %%
import sys

sys.path.append(r"/home/antoniosabotinov/projects/timeseries-project/core")

from interactive_chart import build_chart

fig = build_chart(
    ticker=TICKER,
    interval=INTERVAL,
    start=START,
    end=END,
    indicators=["sma", "ema", "bbands", "rsi", "macd"]
)
fig.show()

# %%
from core.interactive_chart import get_data, build_chart

# Nur die Daten, kein Chart:
df = get_data(ticker=TICKER,
    interval=INTERVAL,
    start=START,
    end=END,
    indicators=["sma", "ema", "bbands", "rsi", "macd"])
df.tail()
# Out:
# Price         ds      Close       High        Low       Open    Volume  \
# 636   2026-07-17  33.619999  34.919998  32.220001  33.790001  47227400
# 637   2026-07-20  40.200001  41.095001  36.310001  36.391998  93338200
# 638   2026-07-21  41.290001  42.680000  40.340000  40.910000  51030000
# 639   2026-07-22  41.279999  43.720001  40.250000  40.299999  41772800
# 640   2026-07-23  40.580002  43.429001  40.349998  40.599998  41864300
#
# Price   SMA_20   SMA_50     EMA_12     EMA_26   BB_MID   BB_UPPER   BB_LOWER  \
# 636    44.2235  52.7140  40.018130  44.998431  44.2235  58.314228  30.132772
# 637    43.2355  52.2984  40.046110  44.642992  43.2355  55.306641  31.164359
# 638    42.4565  51.9872  40.237478  44.394622  42.4565  52.694538  32.218462
# 639    41.7845  51.5888  40.397866  44.163909  41.7845  50.242965  33.326035
# 640    41.2985  51.2974  40.425887  43.898435  41.2985  48.754404  33.842596
#
# Price        RSI      MACD  MACD_SIGNAL  MACD_HIST
# ...

# %%
from core.interactive_chart import build_chart

fig = build_chart("META", interval="1h", start="2026-01-01", end="2026-07-10", indicators=["sma", "rsi"])
fig.show()

# %%
import nbformat
print(nbformat.__version__)
# Out:
# 4.2.0

# %%
import plotly
print(plotly.__version__)
# Out:
# 6.9.0
