# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

# Lokaler Modus - erstellt einen Ordner mit Daten (no server neded)
client = QdrantClient(path="../data/qdrant_books")  # Pfad nicht nach Struktur anpassen

# Test-Collection anlegen
client.create_collection(
    collection_name="test_collection",
    vectors_config=VectorParams(size=768, distance=Distance.COSINE)
)

print(client.get_collections())
# Out:
# collections=[CollectionDescription(name='test_collection')]
